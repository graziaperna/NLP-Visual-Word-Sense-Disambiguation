# %%
#%pip install clean-text

# %%
# import libraries
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from cleantext import clean
import os 
                              
cwd = os.getcwd()

# load messages dataset
data = pd.read_csv(cwd+'\\..\\Dataset\\edos_labelled_aggregated.csv')
data.head()
# Out:
#                   rewire_id  \
# 0   sexism2022_english-9609
# 1  sexism2022_english-16993
# 2  sexism2022_english-13149
# 3  sexism2022_english-13021
# 4    sexism2022_english-966
#
#                                                 text label_sexist  \
# 0  In Nigeria, if you rape a woman, the men rape ...   not sexist
# 1                            Then, she's a keeper. 😉   not sexist
# 2  This is like the Metallica video where the poo...   not sexist
# 3                                             woman?   not sexist
# 4                     I bet she wished she had a gun   not sexist
#
#   label_category label_vector  split
# 0           none         none    dev
# 1           none         none  train
# 2           none         none  train
# 3           none         none  train
# 4           none         none    dev

# %%
dfA_t = pd.DataFrame(data)
dfA_t.head()
# Out:
#                   rewire_id  \
# 0   sexism2022_english-9609
# 1  sexism2022_english-16993
# 2  sexism2022_english-13149
# 3  sexism2022_english-13021
# 4    sexism2022_english-966
#
#                                                 text label_sexist  \
# 0  In Nigeria, if you rape a woman, the men rape ...   not sexist
# 1                            Then, she's a keeper. 😉   not sexist
# 2  This is like the Metallica video where the poo...   not sexist
# 3                                             woman?   not sexist
# 4                     I bet she wished she had a gun   not sexist
#
#   label_category label_vector  split
# 0           none         none    dev
# 1           none         none  train
# 2           none         none  train
# 3           none         none  train
# 4           none         none    dev

# %%
dfA_t=dfA_t.drop('label_vector', axis = 1)
dfA_t=dfA_t.drop('rewire_id', axis = 1)
dfA_d=dfA_t.copy(deep=True)
dfA_s=dfA_t.copy(deep=True)

dfA_t.drop(dfA_t.loc[dfA_t['split']=='dev'].index, inplace=True,axis=0)
dfA_t.drop(dfA_t.loc[dfA_t['split']=='test'].index, inplace=True,axis=0)

dfA_d.drop(dfA_d.loc[dfA_d['split']=='train'].index, inplace=True,axis=0)
dfA_d.drop(dfA_d.loc[dfA_d['split']=='test'].index, inplace=True,axis=0)

dfA_s.drop(dfA_s.loc[dfA_s['split']=='train'].index, inplace=True,axis=0)
dfA_s.drop(dfA_s.loc[dfA_s['split']=='dev'].index, inplace=True,axis=0)

dfA_d=dfA_d.drop('split', axis = 1)
dfA_t=dfA_t.drop('split', axis = 1)
dfA_s=dfA_s.drop('split', axis = 1)

# %%
dfB_d=dfA_d.copy(deep=True)
dfB_d=dfB_d.drop('label_sexist', axis = 1)
dfB_d.drop(dfB_d.loc[dfB_d['label_category']=='none'].index, inplace=True)
dfA_d=dfA_d.drop('label_category', axis = 1)

# %%
dfB_t=dfA_t.copy(deep=True)
dfB_t=dfB_t.drop('label_sexist', axis = 1)
dfB_t.drop(dfB_t.loc[dfB_t['label_category']=='none'].index, inplace=True)
dfA_t=dfA_t.drop('label_category', axis = 1)

# %%
dfB_s=dfA_s.copy(deep=True)
dfB_s=dfB_s.drop('label_sexist', axis = 1)
dfB_s.drop(dfB_s.loc[dfB_s['label_category']=='none'].index, inplace=True)
dfA_s=dfA_s.drop('label_category', axis = 1)

# %%
dfA_t.to_csv(cwd+'\\..\\Dataset\\Processed datasets\\train_sexist.csv', index_label="ID")
dfA_d.to_csv(cwd+'\\..\\Dataset\\Processed datasets\\dev_sexist.csv', index_label="ID")
dfA_s.to_csv(cwd+'\\..\\Dataset\\Processed datasets\\test_sexist.csv', index_label="ID")
dfB_t.to_csv(cwd+'\\..\\Dataset\\Processed datasets\\train_category.csv', index_label="ID")
dfB_d.to_csv(cwd+'\\..\\Dataset\\Processed datasets\\dev_category.csv', index_label="ID")
dfB_s.to_csv(cwd+'\\..\\Dataset\\Processed datasets\\test_category.csv', index_label="ID")
